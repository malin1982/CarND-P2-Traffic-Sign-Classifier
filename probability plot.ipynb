# %% [markdown]
# top 5 value of label2 images= [9.48267877e-01,   5.14664091e-02,   2.62431073e-04,   1.32492403e-06,   1.18910725e-06]
#
# top 5 value indices of label2 images= [ 2, 21, 37,  5, 31]
#
# top 5 value of label4 images= [9.74984527e-01,   1.63620077e-02,   8.63584876e-03,   1.42467788e-05,   1.94216932e-06]
#
# top 5 value indices of label4 images= [ 5,  2,  8, 32,  1]
#
# top 5 value of label25 images= [0.66777545,  0.31711543,  0.00636661,  0.00591293,  0.00167207]
#
# top 5 value indices of label25 images= [ 6, 24, 10, 30, 27]
#
# top 5 value of label31 images= [9.26693857e-01,   7.20231235e-02,   7.34321657e-04,   2.94895261e-04,  1.23034682e-04]
#
# top 5 value indices of label31 images= [17,  3, 41, 25, 34]
#
# top 5 value of label34 images= [9.17524099e-01,   7.99988359e-02,   2.20663822e-03,   2.67154945e-04, 1.70806868e-06]
#
# top 5 value indices of label34 images= [16, 34, 14, 29, 36]

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

# %matplotlib inline

lb2_val = np.asarray([9.48267877e-01, 1.32492403e-06,  5.14664091e-02,  2.62431073e-04, 1.18910725e-06])
lb2_idx = np.asarray([ 2, 5, 21, 37, 31])
lb4_val = np.asarray([1.94216932e-06,   1.63620077e-02, 9.74984527e-01,   8.63584876e-03,   1.42467788e-05])
lb4_idx = np.asarray([ 1,  2, 5, 8, 32 ])
lb25_val = np.asarray([0.66777545,  0.00636661, 0.31711543,   0.00591293,  0.00167207])
lb25_idx = np.asarray([ 6, 10, 24,  30, 27])
lb31_val = np.asarray([ 7.20231235e-02, 9.26693857e-01,  2.94895261e-04,   7.34321657e-04,    1.23034682e-04])
lb31_idx = np.asarray([ 3, 17, 25, 41,  34])
lb34_val = np.asarray([2.20663822e-03, 9.17524099e-01,  2.67154945e-04, 7.99988359e-02,  1.70806868e-06])
lb34_idx = np.asarray([14, 16, 29, 34,  36])

plt.subplot(231)
plt.plot(lb2_idx, lb2_val)
plt.ylabel('Softmax Probability')
plt.title('label2')

plt.subplot(232)
plt.plot(lb4_idx, lb4_val)
plt.ylabel('Softmax Probability')
plt.title('label4')

plt.subplot(233)
plt.plot(lb25_idx, lb25_val)
plt.ylabel('Softmax Probability')
plt.title('label25')

plt.subplot(234)
plt.plot(lb31_idx, lb31_val)
plt.ylabel('Softmax Probability')
plt.title('label31')

plt.subplot(235)
plt.plot(lb34_idx, lb34_val)
plt.ylabel('Softmax Probability')
plt.title('label34')
